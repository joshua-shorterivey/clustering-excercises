# %%
#basic imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

import env
from os.path import exists

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Acquire and Summarize

# %% [markdown]
# You will want to end with a single dataframe. Include the logerror field and all other fields related to the properties that are available. You will end up using all the tables in the database.
#
# - Be sure to do the correct join (inner, outer, etc.). We do not want to eliminate properties purely because they may have a null value for airconditioningtypeid.
# - Only include properties with a transaction in 2017, and include only the last transaction for each property (so no duplicate property ID's), along with zestimate error and date of transaction. (Hint: read the docs for the .duplicated method)
# - Only include properties that have a latitude and longitude value.

# %%
def get_connection(db, user=env.user, host=env.host, password=env.password):
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

def get_zillow_data():
    '''
    Reads in all fields from the customers table in the mall_customers schema from data.codeup.com
    
    parameters: None
    
    returns: a single Pandas DataFrame with the index set to the primary customer_id field
    '''

    sql = """
    SELECT *, properties_2017.id as property_id
    FROM properties_2017 
    LEFT JOIN propertylandusetype USING (propertylandusetypeid)
    LEFT JOIN predictions_2017 USING (parcelid)
    LEFT JOIN unique_properties USING (parcelid)
    LEFT JOIN airconditioningtype USING (airconditioningtypeid)
    LEFT JOIN architecturalstyletype USING (architecturalstyletypeid)
    LEFT JOIN buildingclasstype USING (buildingclasstypeid)
    LEFT JOIN heatingorsystemtype USING (heatingorsystemtypeid)
    LEFT JOIN storytype USING (storytypeid)
    LEFT JOIN typeconstructiontype USING (typeconstructiontypeid)

    WHERE propertylandusedesc IN ("Single Family Residential", "Inferred Single Family Residential") 
        AND transactiondate like '%%2017%%'
    """

    if exists('zillow_data.csv'):
        df = pd.read_csv('zillow_data.csv')
    else:
        df = pd.read_sql(sql, get_connection('zillow'))
    return df

# %%
df = get_zillow_data()

# %%
df = df.drop_duplicates(subset='property_id', keep='last')

# %%
#two brackets to return a dataframe of two columns
# print(df[df.duplicated(subset= 'property_id', keep=False)][['property_id','transactiondate']].sort_values(by=['property_id', 'transactiondate']))
# df[df.duplicated(subset= 'property_id', keep='last')][['property_id','transactiondate']].sort_values(by=['property_id', 'transactiondate'])

# %%
df.info() # --> no nulls in lat/longitude value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52320 entries, 0 to 52440
# Data columns (total 70 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   typeconstructiontypeid        76 non-null     float64
#  1   storytypeid                   47 non-null     float64
#  2   heatingorsystemtypeid         33850 non-null  float64
#  3   buildingclasstypeid           0 non-null      object
#  4   architecturalstyletypeid      70 non-null     float64
#  5   airconditioningtypeid         13615 non-null  float64
#  6   parcelid                      52320 non-null  int64
#  7   propertylandusetypeid         52320 non-null  float64
#  8   id                            52320 non-null  int64
#  9   basementsqft                  47 non-null     float64
#  10  bathroomcnt                   52320 non-null  float64
#  11  bedroomcnt                    52320 non-null  float64
#  12  buildingqualitytypeid         33655 non-null  float64
#  13  calculatedbathnbr             52185 non-null  float64
#  14  decktypeid                    389 non-null    float64
#  15  finishedfloor1squarefeet      4371 non-null   float64
#  16  calculatedfinishedsquarefeet  52239 non-null  float64
#  17  finishedsquarefeet12          52074 non-null  float64
#  18  finishedsquarefeet13          0 non-null      object
#  19  finishedsquarefeet15          0 non-null      object
#  20  finishedsquarefeet50          4371 non-null   float64
#  21  finishedsquarefeet6           165 non-null    float64
#  22  fips                          52320 non-null  float64
#  23  fireplacecnt                  7233 non-null   float64
#  24  fullbathcnt                   52185 non-null  float64
#  25  garagecarcnt                  17984 non-null  float64
#  26  garagetotalsqft               17984 non-null  float64
#  27  hashottuborspa                1514 non-null   float64
#  28  latitude                      52320 non-null  float64
#  29  longitude                     52320 non-null  float64
#  30  lotsizesquarefeet             51954 non-null  float64
#  31  poolcnt                       11077 non-null  float64
#  32  poolsizesum                   865 non-null    float64
#  33  pooltypeid10                  443 non-null    float64
#  34  pooltypeid2                   1071 non-null   float64
#  35  pooltypeid7                   9990 non-null   float64
#  36  propertycountylandusecode     52320 non-null  object
#  37  propertyzoningdesc            33762 non-null  object
#  38  rawcensustractandblock        52320 non-null  float64
#  39  regionidcity                  51284 non-null  float64
#  40  regionidcounty                52320 non-null  float64
#  41  regionidneighborhood          18981 non-null  float64
#  42  regionidzip                   52294 non-null  float64
#  43  roomcnt                       52320 non-null  float64
#  44  threequarterbathnbr           6717 non-null   float64
#  45  unitcnt                       33762 non-null  float64
#  46  yardbuildingsqft17            1935 non-null   float64
#  47  yardbuildingsqft26            63 non-null     float64
#  48  yearbuilt                     52206 non-null  float64
#  49  numberofstories               14532 non-null  float64
#  50  fireplaceflag                 81 non-null     float64
#  51  structuretaxvaluedollarcnt    52238 non-null  float64
#  52  taxvaluedollarcnt             52319 non-null  float64
#  53  assessmentyear                52320 non-null  float64
#  54  landtaxvaluedollarcnt         52319 non-null  float64
#  55  taxamount                     52316 non-null  float64
#  56  taxdelinquencyflag            2068 non-null   object
#  57  taxdelinquencyyear            2068 non-null   float64
#  58  censustractandblock           52199 non-null  float64
#  59  propertylandusedesc           52320 non-null  object
#  60  id                            52320 non-null  int64
#  61  logerror                      52320 non-null  float64
#  62  transactiondate               52320 non-null  object
#  63  airconditioningdesc           13615 non-null  object
#  64  architecturalstyledesc        70 non-null     object
#  65  buildingclassdesc             0 non-null      object
#  66  heatingorsystemdesc           33850 non-null  object
#  67  storydesc                     47 non-null     object
#  68  typeconstructiondesc          76 non-null     object
#  69  property_id                   52320 non-null  int64
# dtypes: float64(52), int64(4), object(14)
# memory usage: 28.3+ MB

# %%
#drops the initial 'id' columns. property_id is a duplicated version for this reason
df.drop(df.columns[60], axis=1, inplace=True)

# %% [markdown]
# Summarize your data (summary stats, info, dtypes, shape, distributions, value_counts, etc.)

# %%
# examine row by row basics:

def nulls_by_row(df):
    num_missing = df.isnull().sum(axis=1)
    prnt_miss = num_missing / df.shape[1] * 100
    rows_missing = pd.DataFrame({'num_cols_missing': num_missing, 'percent_cols_missing': prnt_miss})
    rows_missing = rows_missing.reset_index().groupby(['num_cols_missing', 'percent_cols_missing']).count().reset_index().\

    return rows_missing

# %%
def nulls_by_col(df):
    num_missing = df.isnull().sum()
    percnt_miss = num_missing / df.shape[0] * 100
    cols_missing = pd.DataFrame(
        {
            'num_rows_missing': num_missing,
            'percent_rows_missing': percnt_miss
        }
    )
    return cols_missing

# %%
def summarize(df):
    print('DaataFrame head:\n')
    print(df.head().to_markdown())
    print('-----')
    print('DataFrame info:\n')
    print (df.info())
    print('---')
    print('DataFrame describe:\n')
    print (df.describe())
    print('---')
    print('DataFrame null value asssessment:\n')
    print('Nulls By Column:', nulls_by_col(df))
    print('----')
    print('Nulls By Row:', nulls_by_row(df))
    numerical_cols = df.select_dtypes(exclude='object').columns.to_list()
    categorical_cols = df.select_dtypes(include='object').columns.to_list()
    print('value_counts: \n')
    for col in df.columns:
        print(f'Column Names: {col}')
        if col in categorical_cols:
            print(df[col].value_counts())
        else:
            print(df[col].value_counts(bins=10, sort=False, dropna=False))
            print('---')
    print('Report Finished')
    return

# %%
summarize(df)
# Out:
# DaataFrame head:
#
# |    |   typeconstructiontypeid |   storytypeid |   heatingorsystemtypeid | buildingclasstypeid   |   architecturalstyletypeid |   airconditioningtypeid |   parcelid |   propertylandusetypeid |   basementsqft |   bathroomcnt |   bedroomcnt |   buildingqualitytypeid |   calculatedbathnbr |   decktypeid |   finishedfloor1squarefeet |   calculatedfinishedsquarefeet |   finishedsquarefeet12 | finishedsquarefeet13   | finishedsquarefeet15   |   finishedsquarefeet50 |   finishedsquarefeet6 |   fips |   fireplacecnt |   fullbathcnt |   garagecarcnt |   garagetotalsqft |   hashottuborspa |    latitude |    longitude |   lotsizesquarefeet |   poolcnt |   poolsizesum |   pooltypeid10 |   pooltypeid2 |   pooltypeid7 |   propertycountylandusecode | propertyzoningdesc   |   rawcensustractandblock |   regionidcity |   regionidcounty |   regionidneighborhood |   regionidzip |   roomcnt |   threequarterbathnbr |   unitcnt |   yardbuildingsqft17 |   yardbuildingsqft26 |   yearbuilt |   numberofstories |   fireplaceflag |   structuretaxvaluedollarcnt |   taxvaluedollarcnt |   assessmentyear |   landtaxvaluedollarcnt |   taxamount | taxdelinquencyflag   |   taxdelinquencyyear |   censustractandblock | propertylandusedesc       |    logerror | transactiondate   | airconditioningdesc   | architecturalstyledesc   | buildingclassdesc   | heatingorsystemdesc   | storydesc   | typeconstructiondesc   |   property_id |
# |---:|-------------------------:|--------------:|------------------------:|:----------------------|---------------------------:|------------------------:|-----------:|------------------------:|---------------:|--------------:|-------------:|------------------------:|--------------------:|-------------:|---------------------------:|-------------------------------:|-----------------------:|:-----------------------|:-----------------------|-----------------------:|----------------------:|-------:|---------------:|--------------:|---------------:|------------------:|-----------------:|------------:|-------------:|--------------------:|----------:|--------------:|---------------:|--------------:|--------------:|----------------------------:|:---------------------|-------------------------:|---------------:|-----------------:|-----------------------:|--------------:|----------:|----------------------:|----------:|---------------------:|---------------------:|------------:|------------------:|----------------:|-----------------------------:|--------------------:|-----------------:|------------------------:|------------:|:---------------------|---------------------:|----------------------:|:--------------------------|------------:|:------------------|:----------------------|:-------------------------|:--------------------|:----------------------|:------------|:-----------------------|--------------:|
# |  0 |                      nan |           nan |                     nan |                       |                        nan |                     nan |   14297519 |                     261 |            nan |           3.5 |            4 |                     nan |                 3.5 |          nan |                        nan |                           3100 |                   3100 |                        |                        |                    nan |                   nan |   6059 |            nan |             3 |              2 |               633 |              nan | 3.36349e+07 | -1.17869e+08 |                4506 |       nan |           nan |            nan |           nan |           nan |                         122 |                      |              6.05906e+07 |          53571 |             1286 |                    nan |         96978 |         0 |                     1 |       nan |                  nan |                  nan |        1998 |               nan |             nan |                       485713 |         1.02328e+06 |             2016 |                  537569 |    11013.7  |                      |                  nan |           6.05906e+13 | Single Family Residential |  0.0255949  | 2017-01-01        |                       |                          |                     |                       |             |                        |       1727539 |
# |  1 |                      nan |           nan |                     nan |                       |                        nan |                     nan |   17052889 |                     261 |            nan |           1   |            2 |                     nan |                 1   |          nan |                       1465 |                           1465 |                   1465 |                        |                        |                   1465 |                   nan |   6111 |              1 |             1 |              1 |                 0 |              nan | 3.44493e+07 | -1.19282e+08 |               12647 |       nan |           nan |            nan |           nan |           nan |                        1110 |                      |              6.111e+07   |          13091 |             2061 |                    nan |         97099 |         5 |                   nan |       nan |                  nan |                  nan |        1967 |                 1 |             nan |                        88000 |    464000           |             2016 |                  376000 |     5672.48 |                      |                  nan |           6.111e+13   | Single Family Residential |  0.0556191  | 2017-01-01        |                       |                          |                     |                       |             |                        |       1387261 |
# |  2 |                      nan |           nan |                     nan |                       |                        nan |                     nan |   14186244 |                     261 |            nan |           2   |            3 |                     nan |                 2   |          nan |                        nan |                           1243 |                   1243 |                        |                        |                    nan |                   nan |   6059 |            nan |             2 |              2 |               440 |              nan | 3.38862e+07 | -1.17823e+08 |                8432 |         1 |           nan |            nan |           nan |             1 |                         122 |                      |              6.05902e+07 |          21412 |             1286 |                    nan |         97078 |         6 |                   nan |       nan |                  nan |                  nan |        1962 |                 1 |             nan |                        85289 |    564778           |             2016 |                  479489 |     6488.3  |                      |                  nan |           6.05902e+13 | Single Family Residential |  0.00538285 | 2017-01-01        |                       |                          |                     |                       |             |                        |         11677 |
# |  3 |                      nan |           nan |                       2 |                       |                        nan |                     nan |   12177905 |                     261 |            nan |           3   |            4 |                       8 |                 3   |          nan |                        nan |                           2376 |                   2376 |                        |                        |                    nan |                   nan |   6037 |            nan |             3 |            nan |               nan |              nan | 3.42452e+07 | -1.18241e+08 |               13038 |         1 |           nan |            nan |           nan |             1 |                        0101 | LCR110000*           |              6.0373e+07  |         396551 |             3101 |                    nan |         96330 |         0 |                   nan |         1 |                  nan |                  nan |        1970 |               nan |             nan |                       108918 |    145143           |             2016 |                   36225 |     1777.51 |                      |                  nan |           6.0373e+13  | Single Family Residential | -0.10341    | 2017-01-01        |                       |                          |                     | Central               |             |                        |       2288172 |
# |  4 |                      nan |           nan |                       2 |                       |                        nan |                       1 |   12095076 |                     261 |            nan |           3   |            4 |                       9 |                 3   |          nan |                        nan |                           2962 |                   2962 |                        |                        |                    nan |                   nan |   6037 |            nan |             3 |            nan |               nan |              nan | 3.41452e+07 | -1.1818e+08  |               63000 |         1 |           nan |            nan |           nan |             1 |                        0101 | PSR2                 |              6.03746e+07 |          47019 |             3101 |                 274684 |         96293 |         0 |                   nan |         1 |                  nan |                  nan |        1950 |               nan |             nan |                       276684 |    773303           |             2016 |                  496619 |     9516.26 |                      |                  nan |           6.03746e+13 | Single Family Residential | -0.00101096 | 2017-01-01        | Central               |                          |                     | Central               |             |                        |        781532 |
# -----
# DataFrame info:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52320 entries, 0 to 52440
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   typeconstructiontypeid        76 non-null     float64
#  1   storytypeid                   47 non-null     float64
#  2   heatingorsystemtypeid         33850 non-null  float64
#  3   buildingclasstypeid           0 non-null      object
#  4   architecturalstyletypeid      70 non-null     float64
#  5   airconditioningtypeid         13615 non-null  float64
#  6   parcelid                      52320 non-null  int64
#  7   propertylandusetypeid         52320 non-null  float64
#  8   basementsqft                  47 non-null     float64
#  9   bathroomcnt                   52320 non-null  float64
#  10  bedroomcnt                    52320 non-null  float64
#  11  buildingqualitytypeid         33655 non-null  float64
#  12  calculatedbathnbr             52185 non-null  float64
#  13  decktypeid                    389 non-null    float64
#  14  finishedfloor1squarefeet      4371 non-null   float64
#  15  calculatedfinishedsquarefeet  52239 non-null  float64
#  16  finishedsquarefeet12          52074 non-null  float64
#  17  finishedsquarefeet13          0 non-null      object
#  18  finishedsquarefeet15          0 non-null      object
#  19  finishedsquarefeet50          4371 non-null   float64
#  20  finishedsquarefeet6           165 non-null    float64
#  21  fips                          52320 non-null  float64
#  22  fireplacecnt                  7233 non-null   float64
#  23  fullbathcnt                   52185 non-null  float64
#  24  garagecarcnt                  17984 non-null  float64
#  25  garagetotalsqft               17984 non-null  float64
#  26  hashottuborspa                1514 non-null   float64
#  27  latitude                      52320 non-null  float64
#  28  longitude                     52320 non-null  float64
#  29  lotsizesquarefeet             51954 non-null  float64
#  30  poolcnt                       11077 non-null  float64
#  31  poolsizesum                   865 non-null    float64
#  32  pooltypeid10                  443 non-null    float64
#  33  pooltypeid2                   1071 non-null   float64
#  34  pooltypeid7                   9990 non-null   float64
#  35  propertycountylandusecode     52320 non-null  object
#  36  propertyzoningdesc            33762 non-null  object
#  37  rawcensustractandblock        52320 non-null  float64
#  38  regionidcity                  51284 non-null  float64
#  39  regionidcounty                52320 non-null  float64
#  40  regionidneighborhood          18981 non-null  float64
#  41  regionidzip                   52294 non-null  float64
#  42  roomcnt                       52320 non-null  float64
#  43  threequarterbathnbr           6717 non-null   float64
#  44  unitcnt                       33762 non-null  float64
#  45  yardbuildingsqft17            1935 non-null   float64
#  46  yardbuildingsqft26            63 non-null     float64
#  47  yearbuilt                     52206 non-null  float64
#  48  numberofstories               14532 non-null  float64
#  49  fireplaceflag                 81 non-null     float64
#  50  structuretaxvaluedollarcnt    52238 non-null  float64
#  51  taxvaluedollarcnt             52319 non-null  float64
#  52  assessmentyear                52320 non-null  float64
#  53  landtaxvaluedollarcnt         52319 non-null  float64
#  54  taxamount                     52316 non-null  float64
#  55  taxdelinquencyflag            2068 non-null   object
#  56  taxdelinquencyyear            2068 non-null   float64
#  57  censustractandblock           52199 non-null  float64
#  58  propertylandusedesc           52320 non-null  object
#  59  logerror                      52320 non-null  float64
#  60  transactiondate               52320 non-null  object
#  61  airconditioningdesc           13615 non-null  object
#  62  architecturalstyledesc        70 non-null     object
#  63  buildingclassdesc             0 non-null      object
#  64  heatingorsystemdesc           33850 non-null  object
#  65  storydesc                     47 non-null     object
#  66  typeconstructiondesc          76 non-null     object
#  67  property_id                   52320 non-null  int64
# dtypes: float64(52), int64(2), object(14)
# memory usage: 27.5+ MB
# None
# ---
# DataFrame describe:
#
#        typeconstructiontypeid  storytypeid  heatingorsystemtypeid  \
# count               76.000000         47.0           33850.000000
# mean                 5.973684          7.0               3.965613
# std                  0.229416          0.0               2.562660
# min                  4.000000          7.0               1.000000
# 25%                  6.000000          7.0               2.000000
# 50%                  6.000000          7.0               2.000000
# 75%                  6.000000          7.0               7.000000
# max                  6.000000          7.0              24.000000
#
#        architecturalstyletypeid  airconditioningtypeid      parcelid  \
# count                  70.00000           13615.000000  5.232000e+04
# mean                    7.10000               2.439589  1.299682e+07
# std                     2.66567               3.847925  3.350919e+06
# min                     2.00000               1.000000  1.071186e+07
# 25%                     7.00000               1.000000  1.151018e+07
# 50%                     7.00000               1.000000  1.257829e+07
# 75%                     7.00000               1.000000  1.413036e+07
# max                    21.00000              13.000000  1.676878e+08
#
#        propertylandusetypeid  basementsqft   bathroomcnt    bedroomcnt  ...  \
# count                52320.0     47.000000  52320.000000  52320.000000  ...
# mean                   261.0    678.978723      2.300010      3.300765  ...
# std                      0.0    711.825226      1.022807      0.947555  ...
# min                    261.0     38.000000      0.000000      0.000000  ...
# 25%                    261.0    263.500000      2.000000      3.000000  ...
# 50%                    261.0    512.000000      2.000000      3.000000  ...
# 75%                    261.0    809.500000      3.000000      4.000000  ...
# max                    261.0   3560.000000     18.000000     14.000000  ...
#
#        fireplaceflag  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# count           81.0                5.223800e+04       5.231900e+04
# mean             1.0                1.966362e+05       5.298235e+05
# std              0.0                2.542862e+05       7.518296e+05
# min              1.0                1.290000e+02       1.000000e+03
# 25%              1.0                7.715900e+04       1.940330e+05
# 50%              1.0                1.319050e+05       3.740060e+05
# 75%              1.0                2.264532e+05       6.193540e+05
# max              1.0                9.164901e+06       4.906124e+07
#
#        assessmentyear  landtaxvaluedollarcnt      taxamount  \
# count         52320.0           5.231900e+04   52316.000000
# mean           2016.0           3.334917e+05    6454.743137
# std               0.0           5.705106e+05    8752.477267
# min            2016.0           1.610000e+02      49.180000
# 25%            2016.0           7.619400e+04    2660.982500
# 50%            2016.0           2.180790e+05    4650.565000
# 75%            2016.0           4.087770e+05    7379.270000
# max            2016.0           4.895220e+07  586639.300000
#
#        taxdelinquencyyear  censustractandblock      logerror   property_id
# count         2068.000000         5.219900e+04  52320.000000  5.232000e+04
# mean            14.101064         6.050245e+13      0.018131  1.496906e+06
# std              2.400399         1.861127e+12      0.176905  8.594330e+05
# min              4.000000         6.037101e+13     -4.655420  3.490000e+02
# 25%             14.000000         6.037401e+13     -0.024707  7.576135e+05
# 50%             15.000000         6.037620e+13      0.006934  1.500134e+06
# 75%             15.000000         6.059042e+13      0.040597  2.241333e+06
# max             99.000000         4.830301e+14      5.262999  2.982270e+06
#
# [8 rows x 54 columns]
# ---
# DataFrame null value asssessment:
#
# Nulls By Column:                           num_rows_missing  percent_rows_missing
# typeconstructiontypeid               52244             99.854740
# storytypeid                          52273             99.910168
# heatingorsystemtypeid                18470             35.301988
# buildingclasstypeid                  52320            100.000000
# architecturalstyletypeid             52250             99.866208
# ...                                    ...                   ...
# buildingclassdesc                    52320            100.000000
# heatingorsystemdesc                  18470             35.301988
# storydesc                            52273             99.910168
# typeconstructiondesc                 52244             99.854740
# property_id                              0              0.000000
#
# [68 rows x 2 columns]
# ----
# Nulls By Row:     num_cols_missing  percent_cols_missing  index
# 0                 23             33.823529      2
# 1                 24             35.294118     12
# 2                 25             36.764706     11
# 3                 26             38.235294     30
# 4                 27             39.705882    177
# 5                 28             41.176471    390
# 6                 29             42.647059   2527
# 7                 30             44.117647   2199
# 8                 31             45.588235   5989
# 9                 32             47.058824   8885
# 10                33             48.529412  11967
# 11                34             50.000000  11158
# 12                35             51.470588   3469
# 13                36             52.941176   4138
# 14                37             54.411765   1020
# 15                38             55.882353    223
# 16                39             57.352941     29
# 17                40             58.823529     15
# 18                41             60.294118      6
# 19                42             61.764706      7
# 20                43             63.235294     10
# 21                44             64.705882     46
# 22                45             66.176471      6
# 23                46             67.647059      1
# 24                47             69.117647      1
# 25                48             70.588235      2
# value_counts:
#
# Column Names: typeconstructiontypeid
# (3.9970000000000003, 4.2]     1
# (4.2, 4.4]                    0
# (4.4, 4.6]                    0
# (4.6, 4.8]                    0
# (4.8, 5.0]                    0
# (5.0, 5.2]                    0
# (5.2, 5.4]                    0
# (5.4, 5.6]                    0
# (5.6, 5.8]                    0
# (5.8, 6.0]                   75
# Name: typeconstructiontypeid, dtype: int64
# ---
# Column Names: storytypeid
# (6.992, 6.994]     0
# (6.994, 6.996]     0
# (6.996, 6.997]     0
# (6.997, 6.999]     0
# (6.999, 7.0]      47
# (7.0, 7.001]       0
# (7.001, 7.003]     0
# (7.003, 7.004]     0
# (7.004, 7.006]     0
# (7.006, 7.007]     0
# Name: storytypeid, dtype: int64
# ---
# Column Names: heatingorsystemtypeid
# (0.976, 3.3]    20696
# (3.3, 5.6]          0
# (5.6, 7.9]      13044
# (7.9, 10.2]         2
# (10.2, 12.5]        0
# (12.5, 14.8]       16
# (14.8, 17.1]        0
# (17.1, 19.4]        6
# (19.4, 21.7]       85
# (21.7, 24.0]        1
# Name: heatingorsystemtypeid, dtype: int64
# ---
# Column Names: buildingclasstypeid
# Series([], Name: buildingclasstypeid, dtype: int64)
# Column Names: architecturalstyletypeid
# (1.9800000000000002, 3.9]     5
# (3.9, 5.8]                    0
# (5.8, 7.7]                   62
# (7.7, 9.6]                    1
# (9.6, 11.5]                   0
# (11.5, 13.4]                  0
# (13.4, 15.3]                  0
# (15.3, 17.2]                  0
# (17.2, 19.1]                  0
# (19.1, 21.0]                  2
# Name: architecturalstyletypeid, dtype: int64
# ---
# Column Names: airconditioningtypeid
# (0.987, 2.2]    11873
# (2.2, 3.4]          0
# (3.4, 4.6]          0
# (4.6, 5.8]        159
# (5.8, 7.0]          0
# (7.0, 8.2]          0
# (8.2, 9.4]          0
# (9.4, 10.6]         0
# (10.6, 11.8]       16
# (11.8, 13.0]     1567
# Name: airconditioningtypeid, dtype: int64
# ---
# Column Names: parcelid
# (10554879.015, 26409453.4]    52301
# (26409453.4, 42107051.8]          0
# (42107051.8, 57804650.2]          0
# (57804650.2, 73502248.6]          0
# (73502248.6, 89199847.0]          1
# (89199847.0, 104897445.4]         0
# (104897445.4, 120595043.8]        0
# (120595043.8, 136292642.2]        0
# (136292642.2, 151990240.6]        0
# (151990240.6, 167687839.0]       18
# Name: parcelid, dtype: int64
# ---
# Column Names: propertylandusetypeid
# (260.738, 260.791]        0
# (260.791, 260.843]        0
# (260.843, 260.896]        0
# (260.896, 260.948]        0
# (260.948, 261.0]      52320
# (261.0, 261.052]          0
# (261.052, 261.104]        0
# (261.104, 261.157]        0
# (261.157, 261.209]        0
# (261.209, 261.261]        0
# Name: propertylandusetypeid, dtype: int64
# ---
# Column Names: basementsqft
# (34.477000000000004, 390.2]    20
# (390.2, 742.4]                 13
# (742.4, 1094.6]                 7
# (1094.6, 1446.8]                3
# (1446.8, 1799.0]                0
# (1799.0, 2151.2]                2
# (2151.2, 2503.4]                0
# (2503.4, 2855.6]                0
# (2855.6, 3207.8]                1
# (3207.8, 3560.0]                1
# Name: basementsqft, dtype: int64
# ---
# Column Names: bathroomcnt
# (-0.019, 1.8]    10494
# (1.8, 3.6]       37338
# (3.6, 5.4]        3714
# (5.4, 7.2]         679
# (7.2, 9.0]          85
# (9.0, 10.8]          5
# (10.8, 12.6]         3
# (12.6, 14.4]         1
# (14.4, 16.2]         0
# (16.2, 18.0]         1
# Name: bathroomcnt, dtype: int64
# ---
# Column Names: bedroomcnt
# (-0.015, 1.4]      746
# (1.4, 2.8]        8317
# (2.8, 4.2]       38513
# (4.2, 5.6]        3967
# (5.6, 7.0]         740
# (7.0, 8.4]          24
# (8.4, 9.8]           8
# (9.8, 11.2]          3
# (11.2, 12.6]         1
# (12.6, 14.0]         1
# Name: bedroomcnt, dtype: int64
# ---
# Column Names: buildingqualitytypeid
# (0.988, 2.1]       13
# (2.1, 3.2]        149
# (3.2, 4.3]       8136
# (4.3, 5.4]       1507
# (5.4, 6.5]      10260
# (6.5, 7.6]       3424
# (7.6, 8.7]       8222
# (8.7, 9.8]       1119
# (9.8, 10.9]       230
# (10.9, 12.0]      595
# Name: buildingqualitytypeid, dtype: int64
# ---
# Column Names: calculatedbathnbr
# (0.982, 2.7]    36132
# (2.7, 4.4]      13791
# (4.4, 6.1]       2032
# (6.1, 7.8]        151
# (7.8, 9.5]         69
# (9.5, 11.2]         8
# (11.2, 12.9]        0
# (12.9, 14.6]        1
# (14.6, 16.3]        0
# (16.3, 18.0]        1
# Name: calculatedbathnbr, dtype: int64
# ---
# Column Names: decktypeid
# (65.93299999999999, 65.947]      0
# (65.947, 65.96]                  0
# (65.96, 65.974]                  0
# (65.974, 65.987]                 0
# (65.987, 66.0]                 389
# (66.0, 66.013]                   0
# (66.013, 66.026]                 0
# (66.026, 66.04]                  0
# (66.04, 66.053]                  0
# (66.053, 66.066]                 0
# Name: decktypeid, dtype: int64
# ---
# Column Names: finishedfloor1squarefeet
# (177.271, 856.8]     311
# (856.8, 1529.6]     2308
# (1529.6, 2202.4]    1265
# (2202.4, 2875.2]     276
# (2875.2, 3548.0]     123
# (3548.0, 4220.8]      43
# (4220.8, 4893.6]      24
# (4893.6, 5566.4]      12
# (5566.4, 6239.2]       5
# (6239.2, 6912.0]       4
# Name: finishedfloor1squarefeet, dtype: int64
# ---
# Column Names: calculatedfinishedsquarefeet
# (106.198, 2308.1]     39201
# (2308.1, 4488.2]      11815
# (4488.2, 6668.3]       1004
# (6668.3, 8848.4]        158
# (8848.4, 11028.5]        42
# (11028.5, 13208.6]       12
# (13208.6, 15388.7]        2
# (15388.7, 17568.8]        2
# (17568.8, 19748.9]        1
# (19748.9, 21929.0]        2
# Name: calculatedfinishedsquarefeet, dtype: int64
# ---
# Column Names: finishedsquarefeet12
# (106.198, 2308.1]     39052
# (2308.1, 4488.2]      11800
# (4488.2, 6668.3]       1003
# (6668.3, 8848.4]        158
# (8848.4, 11028.5]        42
# (11028.5, 13208.6]       12
# (13208.6, 15388.7]        2
# (15388.7, 17568.8]        2
# (17568.8, 19748.9]        1
# (19748.9, 21929.0]        2
# Name: finishedsquarefeet12, dtype: int64
# ---
# Column Names: finishedsquarefeet13
# Series([], Name: finishedsquarefeet13, dtype: int64)
# Column Names: finishedsquarefeet15
# Series([], Name: finishedsquarefeet15, dtype: int64)
# Column Names: finishedsquarefeet50
# (171.716, 1412.3]     2177
# (1412.3, 2640.6]      1903
# (2640.6, 3868.9]       210
# (3868.9, 5097.2]        57
# (5097.2, 6325.5]        13
# (6325.5, 7553.8]         7
# (7553.8, 8782.1]         2
# (8782.1, 10010.4]        1
# (10010.4, 11238.7]       0
# (11238.7, 12467.0]       1
# Name: finishedsquarefeet50, dtype: int64
# ---
# Column Names: finishedsquarefeet6
# (374.781, 901.8]    57
# (901.8, 1423.6]     72
# (1423.6, 1945.4]    16
# (1945.4, 2467.2]     8
# (2467.2, 2989.0]     4
# (2989.0, 3510.8]     3
# (3510.8, 4032.6]     2
# (4032.6, 4554.4]     2
# (4554.4, 5076.2]     0
# (5076.2, 5598.0]     1
# Name: finishedsquarefeet6, dtype: int64
# ---
# Column Names: fips
# (6036.925, 6044.4]    33824
# (6044.4, 6051.8]          0
# (6051.8, 6059.2]      14111
# (6059.2, 6066.6]          0
# (6066.6, 6074.0]          0
# (6074.0, 6081.4]          0
# (6081.4, 6088.8]          0
# (6088.8, 6096.2]          0
# (6096.2, 6103.6]          0
# (6103.6, 6111.0]       4385
# Name: fips, dtype: int64
# ---
# Column Names: fireplacecnt
# (0.995, 1.4]    6024
# (1.4, 1.8]         0
# (1.8, 2.2]       942
# (2.2, 2.6]         0
# (2.6, 3.0]       229
# (3.0, 3.4]         0
# (3.4, 3.8]         0
# (3.8, 4.2]        35
# (4.2, 4.6]         0
# (4.6, 5.0]         3
# Name: fireplacecnt, dtype: int64
# ---
# Column Names: fullbathcnt
# (0.982, 2.7]    36144
# (2.7, 4.4]      14487
# (4.4, 6.1]       1379
# (6.1, 7.8]         96
# (7.8, 9.5]         69
# (9.5, 11.2]         8
# (11.2, 12.9]        0
# (12.9, 14.6]        1
# (14.6, 16.3]        0
# (16.3, 18.0]        1
# Name: fullbathcnt, dtype: int64
# ---
# Column Names: garagecarcnt
# (-0.015, 1.4]     2262
# (1.4, 2.8]       14777
# (2.8, 4.2]         874
# (4.2, 5.6]          45
# (5.6, 7.0]          16
# (7.0, 8.4]           2
# (8.4, 9.8]           2
# (9.8, 11.2]          4
# (11.2, 12.6]         0
# (12.6, 14.0]         2
# Name: garagecarcnt, dtype: int64
# ---
# Column Names: garagetotalsqft
# (-4.252000000000001, 425.1]     4447
# (425.1, 850.2]                 13160
# (850.2, 1275.3]                  323
# (1275.3, 1700.4]                  38
# (1700.4, 2125.5]                   6
# (2125.5, 2550.6]                   2
# (2550.6, 2975.7]                   4
# (2975.7, 3400.8]                   2
# (3400.8, 3825.9]                   1
# (3825.9, 4251.0]                   1
# Name: garagetotalsqft, dtype: int64
# ---
# Column Names: hashottuborspa
# (0.9989, 0.9992]       0
# (0.9992, 0.9994]       0
# (0.9994, 0.9996]       0
# (0.9996, 0.9998]       0
# (0.9998, 1.0]       1514
# (1.0, 1.0002]          0
# (1.0002, 1.0004]       0
# (1.0004, 1.0006]       0
# (1.0006, 1.0008]       0
# (1.0008, 1.001]        0
# Name: hashottuborspa, dtype: int64
# ---
# Column Names: latitude
# (33339141.852, 33488434.7]      758
# (33488434.7, 33636249.4]       3223
# (33636249.4, 33784064.1]       6071
# (33784064.1, 33931878.8]      10933
# (33931878.8, 34079693.5]       9032
# (34079693.5, 34227508.2]      12438
# (34227508.2, 34375322.9]       4610
# (34375322.9, 34523137.6]       1823
# (34523137.6, 34670952.3]       2185
# (34670952.3, 34818767.0]       1247
# Name: latitude, dtype: int64
# ---
# Column Names: longitude
# (-119477336.781, -119283338.0]      161
# (-119283338.0, -119091260.0]       1299
# (-119091260.0, -118899182.0]       1063
# (-118899182.0, -118707104.0]       1781
# (-118707104.0, -118515026.0]       3844
# (-118515026.0, -118322948.0]       9321
# (-118322948.0, -118130870.0]      10022
# (-118130870.0, -117938792.0]      11211
# (-117938792.0, -117746714.0]       9146
# (-117746714.0, -117554636.0]       4472
# Name: longitude, dtype: int64
# ---
# Column Names: lotsizesquarefeet
# (-6734.775000000001, 697313.4]    51934
# (697313.4, 1394390.8]                 9
# (1394390.8, 2091468.2]                2
# (2091468.2, 2788545.6]                1
# (2788545.6, 3485623.0]                1
# (3485623.0, 4182700.4]                0
# (4182700.4, 4879777.8]                0
# (4879777.8, 5576855.2]                0
# (5576855.2, 6273932.6]                0
# (6273932.6, 6971010.0]                7
# Name: lotsizesquarefeet, dtype: int64
# ---
# Column Names: poolcnt
# (0.9989, 0.9992]        0
# (0.9992, 0.9994]        0
# (0.9994, 0.9996]        0
# (0.9996, 0.9998]        0
# (0.9998, 1.0]       11077
# (1.0, 1.0002]           0
# (1.0002, 1.0004]        0
# (1.0004, 1.0006]        0
# (1.0006, 1.0008]        0
# (1.0008, 1.001]         0
# Name: poolcnt, dtype: int64
# ---
# Column Names: poolsizesum
# (22.523, 171.6]       7
# (171.6, 319.2]       46
# (319.2, 466.8]      321
# (466.8, 614.4]      306
# (614.4, 762.0]      123
# (762.0, 909.6]       48
# (909.6, 1057.2]       7
# (1057.2, 1204.8]      5
# (1204.8, 1352.4]      0
# (1352.4, 1500.0]      2
# Name: poolsizesum, dtype: int64
# ---
# Column Names: pooltypeid10
# (0.9989, 0.9992]      0
# (0.9992, 0.9994]      0
# (0.9994, 0.9996]      0
# (0.9996, 0.9998]      0
# (0.9998, 1.0]       443
# (1.0, 1.0002]         0
# (1.0002, 1.0004]      0
# (1.0004, 1.0006]      0
# (1.0006, 1.0008]      0
# (1.0008, 1.001]       0
# Name: pooltypeid10, dtype: int64
# ---
# Column Names: pooltypeid2
# (0.9989, 0.9992]       0
# (0.9992, 0.9994]       0
# (0.9994, 0.9996]       0
# (0.9996, 0.9998]       0
# (0.9998, 1.0]       1071
# (1.0, 1.0002]          0
# (1.0002, 1.0004]       0
# (1.0004, 1.0006]       0
# (1.0006, 1.0008]       0
# (1.0008, 1.001]        0
# Name: pooltypeid2, dtype: int64
# ---
# Column Names: pooltypeid7
# (0.9989, 0.9992]       0
# (0.9992, 0.9994]       0
# (0.9994, 0.9996]       0
# (0.9996, 0.9998]       0
# (0.9998, 1.0]       9990
# (1.0, 1.0002]          0
# (1.0002, 1.0004]       0
# (1.0004, 1.0006]       0
# (1.0006, 1.0008]       0
# (1.0008, 1.001]        0
# Name: pooltypeid7, dtype: int64
# ---
# Column Names: propertycountylandusecode
# 0100    26714
# 122     13045
# 0101     6399
# 1111     3353
# 1        1066
# 1110     1024
# 0104      367
# 010G       93
# 0103       91
# 0108       57
# 010M       52
# 0109       18
# 1112        8
# 0110        6
# 0113        6
# 0141        4
# 0102        3
# 0105        3
# 010V        2
# 0111        2
# 0130        2
# 0131        1
# 0133        1
# 0115        1
# 010L        1
# 0114        1
# Name: propertycountylandusecode, dtype: int64
# Column Names: propertyzoningdesc
# LAR1          6480
# LARS          1380
# LBR1N         1109
# SCUR2          712
# LARE11         611
#               ...
# LCR3800015       1
# PSR6*            1
# LARE             1
# MYR3PY           1
# BFA15000*        1
# Name: propertyzoningdesc, Length: 1286, dtype: int64
# Column Names: rawcensustractandblock
# (60370272.019999996, 60444919.091]    33824
# (60444919.091, 60518827.081]              0
# (60518827.081, 60592735.071]          14111
# (60592735.071, 60666643.061]              0
# (60666643.061, 60740551.052]              0
# (60740551.052, 60814459.042]              0
# (60814459.042, 60888367.032]              0
# (60888367.032, 60962275.022]              0
# (60962275.022, 61036183.012]              0
# (61036183.012, 61110091.002]           4385
# Name: rawcensustractandblock, dtype: int64
# ---
# Column Names: regionidcity
# (3097.9339999999997, 42797.5]    39081
# (42797.5, 82104.0]               10582
# (82104.0, 121410.5]                824
# (121410.5, 160717.0]                 0
# (160717.0, 200023.5]                 0
# (200023.5, 239330.0]                 0
# (239330.0, 278636.5]                17
# (278636.5, 317943.0]                 0
# (317943.0, 357249.5]                 0
# (357249.5, 396556.0]               780
# Name: regionidcity, dtype: int64
# ---
# Column Names: regionidcounty
# (1284.184, 1467.5]    14111
# (1467.5, 1649.0]          0
# (1649.0, 1830.5]          0
# (1830.5, 2012.0]          0
# (2012.0, 2193.5]       4385
# (2193.5, 2375.0]          0
# (2375.0, 2556.5]          0
# (2556.5, 2738.0]          0
# (2738.0, 2919.5]          0
# (2919.5, 3101.0]      33824
# Name: regionidcounty, dtype: int64
# ---
# Column Names: regionidneighborhood
# (6194.784, 82673.5]     7255
# (82673.5, 158395.0]     2991
# (158395.0, 234116.5]      32
# (234116.5, 309838.0]    7129
# (309838.0, 385559.5]       7
# (385559.5, 461281.0]     922
# (461281.0, 537002.5]       0
# (537002.5, 612724.0]       0
# (612724.0, 688445.5]      66
# (688445.5, 764167.0]     579
# Name: regionidneighborhood, dtype: int64
# ---
# Column Names: regionidzip
# (95678.306, 126351.3]    52282
# (126351.3, 156720.6]         0
# (156720.6, 187089.9]         0
# (187089.9, 217459.2]         0
# (217459.2, 247828.5]         0
# (247828.5, 278197.8]         0
# (278197.8, 308567.1]         0
# (308567.1, 338936.4]         0
# (338936.4, 369305.7]         0
# (369305.7, 399675.0]        12
# Name: regionidzip, dtype: int64
# ---
# Column Names: roomcnt
# (-0.016, 1.5]    37762
# (1.5, 3.0]          91
# (3.0, 4.5]         518
# (4.5, 6.0]        5860
# (6.0, 7.5]        3608
# (7.5, 9.0]        3983
# (9.0, 10.5]        338
# (10.5, 12.0]       143
# (12.0, 13.5]        10
# (13.5, 15.0]         7
# Name: roomcnt, dtype: int64
# ---
# Column Names: threequarterbathnbr
# (0.993, 1.6]    6638
# (1.6, 2.2]        70
# (2.2, 2.8]         0
# (2.8, 3.4]         8
# (3.4, 4.0]         0
# (4.0, 4.6]         0
# (4.6, 5.2]         0
# (5.2, 5.8]         0
# (5.8, 6.4]         0
# (6.4, 7.0]         1
# Name: threequarterbathnbr, dtype: int64
# ---
# Column Names: unitcnt
# (0.997, 1.2]    33734
# (1.2, 1.4]          0
# (1.4, 1.6]          0
# (1.6, 1.8]          0
# (1.8, 2.0]         27
# (2.0, 2.2]          0
# (2.2, 2.4]          0
# (2.4, 2.6]          0
# (2.6, 2.8]          0
# (2.8, 3.0]          1
# Name: unitcnt, dtype: int64
# ---
# Column Names: yardbuildingsqft17
# (7.819, 329.0]      1218
# (329.0, 647.0]       571
# (647.0, 965.0]        95
# (965.0, 1283.0]       34
# (1283.0, 1601.0]       9
# (1601.0, 1919.0]       1
# (1919.0, 2237.0]       2
# (2237.0, 2555.0]       2
# (2555.0, 2873.0]       1
# (2873.0, 3191.0]       2
# Name: yardbuildingsqft17, dtype: int64
# ---
# Column Names: yardbuildingsqft26
# (11.143, 97.6]    19
# (97.6, 183.2]     13
# (183.2, 268.8]    10
# (268.8, 354.4]     7
# (354.4, 440.0]     4
# (440.0, 525.6]     6
# (525.6, 611.2]     1
# (611.2, 696.8]     1
# (696.8, 782.4]     1
# (782.4, 868.0]     1
# Name: yardbuildingsqft26, dtype: int64
# ---
# Column Names: yearbuilt
# (1877.861, 1891.8]       22
# (1891.8, 1905.6]        168
# (1905.6, 1919.4]       1024
# (1919.4, 1933.2]       4077
# (1933.2, 1947.0]       4893
# (1947.0, 1960.8]      15896
# (1960.8, 1974.6]      10205
# (1974.6, 1988.4]       6942
# (1988.4, 2002.2]       5920
# (2002.2, 2016.0]       3059
# Name: yearbuilt, dtype: int64
# ---
# Column Names: numberofstories
# (0.994, 1.5]    8868
# (1.5, 2.0]      5312
# (2.0, 2.5]         0
# (2.5, 3.0]       351
# (3.0, 3.5]         0
# (3.5, 4.0]         0
# (4.0, 4.5]         0
# (4.5, 5.0]         0
# (5.0, 5.5]         0
# (5.5, 6.0]         1
# Name: numberofstories, dtype: int64
# ---
# Column Names: fireplaceflag
# (0.9989, 0.9992]     0
# (0.9992, 0.9994]     0
# (0.9994, 0.9996]     0
# (0.9996, 0.9998]     0
# (0.9998, 1.0]       81
# (1.0, 1.0002]        0
# (1.0002, 1.0004]     0
# (1.0004, 1.0006]     0
# (1.0006, 1.0008]     0
# (1.0008, 1.001]      0
# Name: fireplaceflag, dtype: int64
# ---
# Column Names: structuretaxvaluedollarcnt
# (-9035.773000000001, 916606.2]    51304
# (916606.2, 1833083.4]               769
# (1833083.4, 2749560.6]              105
# (2749560.6, 3666037.8]               37
# (3666037.8, 4582515.0]                8
# (4582515.0, 5498992.2]                7
# (5498992.2, 6415469.4]                2
# (6415469.4, 7331946.6]                1
# (7331946.6, 8248423.8]                4
# (8248423.8, 9164901.0]                1
# Name: structuretaxvaluedollarcnt, dtype: int64
# ---
# Column Names: taxvaluedollarcnt
# (-48060.236999999994, 4907023.6]    52111
# (4907023.6, 9813047.2]                171
# (9813047.2, 14719070.8]                23
# (14719070.8, 19625094.4]                8
# (19625094.4, 24531118.0]                4
# (24531118.0, 29437141.6]                1
# (29437141.6, 34343165.2]                0
# (34343165.2, 39249188.8]                0
# (39249188.8, 44155212.4]                0
# (44155212.4, 49061236.0]                1
# Name: taxvaluedollarcnt, dtype: int64
# ---
# Column Names: assessmentyear
# (2013.983, 2014.387]        0
# (2014.387, 2014.79]         0
# (2014.79, 2015.194]         0
# (2015.194, 2015.597]        0
# (2015.597, 2016.0]      52320
# (2016.0, 2016.403]          0
# (2016.403, 2016.806]        0
# (2016.806, 2017.21]         0
# (2017.21, 2017.613]         0
# (2017.613, 2018.016]        0
# Name: assessmentyear, dtype: int64
# ---
# Column Names: landtaxvaluedollarcnt
# (-48791.03799999999, 4895364.7]    52213
# (4895364.7, 9790568.4]                86
# (9790568.4, 14685772.1]               13
# (14685772.1, 19580975.8]               5
# (19580975.8, 24476179.5]               1
# (24476179.5, 29371383.2]               0
# (29371383.2, 34266586.9]               0
# (34266586.9, 39161790.6]               0
# (39161790.6, 44056994.3]               0
# (44056994.3, 48952198.0]               1
# Name: landtaxvaluedollarcnt, dtype: int64
# ---
# Column Names: taxamount
# (-537.411, 58708.192]       52118
# (58708.192, 117367.204]       165
# (117367.204, 176026.216]       19
# (176026.216, 234685.228]        9
# (234685.228, 293344.24]         4
# (293344.24, 352003.252]         0
# (352003.252, 410662.264]        0
# (410662.264, 469321.276]        0
# (469321.276, 527980.288]        0
# (527980.288, 586639.3]          1
# Name: taxamount, dtype: int64
# ---
# Column Names: taxdelinquencyflag
# Y    2068
# Name: taxdelinquencyflag, dtype: int64
# Column Names: taxdelinquencyyear
# (3.904, 13.5]     384
# (13.5, 23.0]     1683
# (23.0, 32.5]        0
# (32.5, 42.0]        0
# (42.0, 51.5]        0
# (51.5, 61.0]        0
# (61.0, 70.5]        0
# (70.5, 80.0]        0
# (80.0, 89.5]        0
# (89.5, 99.0]        1
# Name: taxdelinquencyyear, dtype: int64
# ---
# Column Names: censustractandblock
# (59948352007016.984, 102636920499301.5]    52198
# (102636920499301.5, 144902829897603.0]         0
# (144902829897603.0, 187168739295904.5]         0
# (187168739295904.5, 229434648694206.03]        0
# (229434648694206.03, 271700558092507.5]        0
# (271700558092507.5, 313966467490809.0]         0
# (313966467490809.0, 356232376889110.5]         0
# (356232376889110.5, 398498286287411.94]        0
# (398498286287411.94, 440764195685713.5]        0
# (440764195685713.5, 483030105084015.0]         1
# Name: censustractandblock, dtype: int64
# ---
# Column Names: propertylandusedesc
# Single Family Residential    52320
# Name: propertylandusedesc, dtype: int64
# Column Names: logerror
# (-4.666, -3.664]        2
# (-3.664, -2.672]        0
# (-2.672, -1.68]        26
# (-1.68, -0.688]       109
# (-0.688, 0.304]     50830
# (0.304, 1.296]       1220
# (1.296, 2.287]         76
# (2.287, 3.279]         55
# (3.279, 4.271]          1
# (4.271, 5.263]          1
# Name: logerror, dtype: int64
# ---
# Column Names: transactiondate
# 2017-06-30    809
# 2017-04-28    614
# 2017-05-31    565
# 2017-07-28    546
# 2017-08-31    528
#              ...
# 2017-05-07      1
# 2017-05-13      1
# 2017-05-20      1
# 2017-06-11      1
# 2017-09-25      1
# Name: transactiondate, Length: 257, dtype: int64
# Column Names: airconditioningdesc
# Central      11873
# Yes           1567
# None           159
# Wall Unit       16
# Name: airconditioningdesc, dtype: int64
# Column Names: architecturalstyledesc
# Contemporary     62
# Cape Cod          3
# Bungalow          2
# Ranch/Rambler     2
# Conventional      1
# Name: architecturalstyledesc, dtype: int64
# Column Names: buildingclassdesc
# Series([], Name: buildingclassdesc, dtype: int64)
# Column Names: heatingorsystemdesc
# Central       20689
# Floor/Wall    12527
# Forced air      517
# Solar            85
# None             16
# Baseboard         7
# Radiant           6
# Gravity           2
# Yes               1
# Name: heatingorsystemdesc, dtype: int64
# Column Names: storydesc
# Basement    47
# Name: storydesc, dtype: int64
# Column Names: typeconstructiondesc
# Frame       75
# Concrete     1
# Name: typeconstructiondesc, dtype: int64
# Column Names: property_id
# (-2632.922, 298541.1]     5167
# (298541.1, 596733.2]      5137
# (596733.2, 894925.3]      5139
# (894925.3, 1193117.4]     5249
# (1193117.4, 1491309.5]    5316
# (1491309.5, 1789501.6]    5346
# (1789501.6, 2087693.7]    5244
# (2087693.7, 2385885.8]    5181
# (2385885.8, 2684077.9]    5240
# (2684077.9, 2982270.0]    5301
# Name: property_id, dtype: int64
# ---
# Report Finished

# %% [markdown]
# ### Takeaways
# *

# %% [markdown]
# Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values.

# %%
cols_missing = nulls_by_col(df)

# %%
print(cols_missing)
# Out:
#                           num_rows_missing  percent_rows_missing
# typeconstructiontypeid               52244             99.854740
# storytypeid                          52273             99.910168
# heatingorsystemtypeid                18470             35.301988
# buildingclasstypeid                  52320            100.000000
# architecturalstyletypeid             52250             99.866208
# ...                                    ...                   ...
# buildingclassdesc                    52320            100.000000
# heatingorsystemdesc                  18470             35.301988
# storydesc                            52273             99.910168
# typeconstructiondesc                 52244             99.854740
# property_id                              0              0.000000
#
# [68 rows x 2 columns]

# %% [markdown]
# ### Takeaways
# * Can get rid of the id columns that were used for join. typeconstructionid, storytypeid, etc
# * anything below 95% should be dropped
# * actually after some research we are going to go with 64%
# * want to investigate garagecarcnt, heatingorsystemdesc, airconditiontiontypeid, aircondtioningdesc

# %% [markdown]
# # Prepare
#
# Remove any properties that are likely to be something other than single unit properties. (e.g. no duplexes, no land/lot, ...). There are multiple ways to estimate that a property is a single unit, and there is not a single "right" answer.

# %% [markdown]
# #### Takeaways
# * does not appear to be any of those properties in the dataframe
# * pulled in only single family residential or inferred single family residential

# %% [markdown]
# ### Create a function that will drop rows or columns based on the percent of values that are missing:
# `handle_missing_values(df, prop_required_column, prop_required_row)`
#
# > The input:
# * A dataframe
# * A number between 0 and 1 that represents the proportion, for each column, of rows with non-missing values required to keep the column.
#    - i.e. if prop_required_column = .6, then you are requiring a column to have at least 60% of values not-NA (no more than 40% missing).
# * A number between 0 and 1 that represents the proportion, for each row, of columns/variables with non-missing values required to keep the row.
#    - For example, if prop_required_row = .75, then you are requiring a row to have at least 75% of variables with a non-missing value (no more that 25% missing).
# > The output:
# * The dataframe with the columns and rows dropped as indicated.
#    - Be sure to drop the columns prior to the rows in your function.
#    - hint: Look up the dropna documentation.
# > You will want to compute a threshold from your input values (prop_required) and total number of rows or columns.

# %%
dfb = df.copy(deep=True)

# %%
def handle_missing_values(df, prop_required_columns=0.60, prop_required_row=0.75):
    threshold = int(round(prop_required_columns * len(df.index), 0))
    df = df.dropna(axis=1, thresh=threshold)
    threshold = int(round(prop_required_row * len(df.columns), 0))
    df = df.dropna(axis=0, thresh=threshold)

    return df

# %%
df = handle_missing_values(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52242 entries, 0 to 52440
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   heatingorsystemtypeid         33850 non-null  float64
#  1   parcelid                      52242 non-null  int64
#  2   propertylandusetypeid         52242 non-null  float64
#  3   bathroomcnt                   52242 non-null  float64
#  4   bedroomcnt                    52242 non-null  float64
#  5   buildingqualitytypeid         33654 non-null  float64
#  6   calculatedbathnbr             52181 non-null  float64
#  7   calculatedfinishedsquarefeet  52234 non-null  float64
#  8   finishedsquarefeet12          52070 non-null  float64
#  9   fips                          52242 non-null  float64
#  10  fullbathcnt                   52181 non-null  float64
#  11  latitude                      52242 non-null  float64
#  12  longitude                     52242 non-null  float64
#  13  lotsizesquarefeet             51885 non-null  float64
#  14  propertycountylandusecode     52242 non-null  object
#  15  propertyzoningdesc            33745 non-null  object
#  16  rawcensustractandblock        52242 non-null  float64
#  17  regionidcity                  51217 non-null  float64
#  18  regionidcounty                52242 non-null  float64
#  19  regionidzip                   52223 non-null  float64
#  20  roomcnt                       52242 non-null  float64
#  21  unitcnt                       33762 non-null  float64
#  22  yearbuilt                     52201 non-null  float64
#  23  structuretaxvaluedollarcnt    52170 non-null  float64
#  24  taxvaluedollarcnt             52241 non-null  float64
#  25  assessmentyear                52242 non-null  float64
#  26  landtaxvaluedollarcnt         52241 non-null  float64
#  27  taxamount                     52238 non-null  float64
#  28  censustractandblock           52134 non-null  float64
#  29  propertylandusedesc           52242 non-null  object
#  30  logerror                      52242 non-null  float64
#  31  transactiondate               52242 non-null  object
#  32  heatingorsystemdesc           33850 non-null  object
#  33  property_id                   52242 non-null  int64
# dtypes: float64(27), int64(2), object(5)
# memory usage: 14.0+ MB

# %% [markdown]
# Encapsulate your work inside of functions in a wrangle_zillow.py module.
